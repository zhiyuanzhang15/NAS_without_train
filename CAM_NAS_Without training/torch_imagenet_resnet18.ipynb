# %%
import torchvision

teseset = torchvision.datasets.ImageNet(root='../data/torch_imagenet', split='val')

# %%
import torch
import torchvision
import torch.utils.data as data
import torchvision.transforms as transforms

# %%
if __name__ == "__main__":
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

    transform = transforms.Compose(
        [transforms.Resize(256),
         transforms.CenterCrop(224),
         transforms.ToTensor(),
         normalize,
         ])

    test_set = torchvision.datasets.ImageNet(root='../data/torch_imagenet', transform=transform, split='val')
    test_loader = data.DataLoader(test_set, batch_size=100, shuffle=True, num_workers=4)

    model = torchvision.models.resnet18(pretrained=True).to(device)
    model.eval()

    correct_top1 = 0
    correct_top5 = 0
    total = 0

    with torch.no_grad():
        for idx, (images, labels) in enumerate(test_loader):

            images = images.to(device)      # [100, 3, 224, 224]
            labels = labels.to(device)      # [100]
            outputs = model(images)

            # ------------------------------------------------------------------------------
            # rank 1
            _, pred = torch.max(outputs, 1)
            total += labels.size(0)
            correct_top1 += (pred == labels).sum().item()

            # ------------------------------------------------------------------------------
            # rank 5
            _, rank5 = outputs.topk(5, 1, True, True)
            rank5 = rank5.t()
            correct5 = rank5.eq(labels.view(1, -1).expand_as(rank5))

            # ------------------------------------------------------------------------------
            for k in range(6):
                correct_k = correct5[:k].reshape(-1).float().sum(0, keepdim=True)

            correct_top5 += correct_k.item()

            print("step : {} / {}".format(idx + 1, len(test_set)/int(labels.size(0))))
            print("top-1 percentage :  {0:0.2f}%".format(correct_top1 / total * 100))
            print("top-5 percentage :  {0:0.2f}%".format(correct_top5 / total * 100))
            
    print("top-1 percentage :  {0:0.2f}%".format(correct_top1 / total * 100))
    print("top-5 percentage :  {0:0.2f}%".format(correct_top5 / total * 100))
# Out:
# step : 1 / 500.0
# top-1 percentage :  70.00%
# top-5 percentage :  87.00%
# step : 2 / 500.0
# top-1 percentage :  68.00%
# top-5 percentage :  88.00%
# step : 3 / 500.0
# top-1 percentage :  67.33%
# top-5 percentage :  88.67%
# step : 4 / 500.0
# top-1 percentage :  67.50%
# top-5 percentage :  89.50%
# step : 5 / 500.0
# top-1 percentage :  68.20%
# top-5 percentage :  90.00%
# step : 6 / 500.0
# top-1 percentage :  68.00%
# top-5 percentage :  89.17%
# step : 7 / 500.0
# top-1 percentage :  68.43%
# top-5 percentage :  89.43%
# step : 8 / 500.0
# top-1 percentage :  68.38%
# top-5 percentage :  89.12%
# step : 9 / 500.0
# top-1 percentage :  69.44%
# top-5 percentage :  89.33%
# step : 10 / 500.0
# top-1 percentage :  70.10%
# top-5 percentage :  90.10%
# step : 11 / 500.0
# top-1 percentage :  70.73%
# top-5 percentage :  90.00%
# step : 12 / 500.0
# top-1 percentage :  70.50%
# top-5 percentage :  90.08%
# step : 13 / 500.0
# top-1 percentage :  70.00%
# top-5 percentage :  90.00%
# step : 14 / 500.0
# top-1 percentage :  70.00%
# top-5 percentage :  89.93%
# step : 15 / 500.0
# top-1 percentage :  70.13%
# top-5 percentage :  89.87%
# step : 16 / 500.0
# top-1 percentage :  70.38%
# top-5 percentage :  89.75%
# step : 17 / 500.0
# top-1 percentage :  70.41%
# top-5 percentage :  89.59%
# step : 18 / 500.0
# top-1 percentage :  70.78%
# top-5 percentage :  89.56%
# step : 19 / 500.0
# top-1 percentage :  71.11%
# top-5 percentage :  89.74%
# step : 20 / 500.0
# top-1 percentage :  71.05%
# top-5 percentage :  89.80%
# step : 21 / 500.0
# top-1 percentage :  71.33%
# top-5 percentage :  89.67%
# step : 22 / 500.0
# top-1 percentage :  70.95%
# top-5 percentage :  89.41%
# step : 23 / 500.0
# top-1 percentage :  71.00%
# top-5 percentage :  89.35%
# step : 24 / 500.0
# top-1 percentage :  70.79%
# top-5 percentage :  89.25%
# step : 25 / 500.0
# top-1 percentage :  70.88%
# top-5 percentage :  89.24%
# step : 26 / 500.0
# top-1 percentage :  70.69%
# top-5 percentage :  89.08%
# step : 27 / 500.0
# top-1 percentage :  70.67%
# top-5 percentage :  89.00%
# step : 28 / 500.0
# top-1 percentage :  70.75%
# top-5 percentage :  89.21%
# step : 29 / 500.0
# top-1 percentage :  70.79%
# top-5 percentage :  89.17%
# step : 30 / 500.0
# top-1 percentage :  70.53%
# top-5 percentage :  89.20%
# step : 31 / 500.0
# top-1 percentage :  70.42%
# top-5 percentage :  89.23%
# step : 32 / 500.0
# top-1 percentage :  70.22%
# top-5 percentage :  89.22%
# step : 33 / 500.0
# top-1 percentage :  70.21%
# top-5 percentage :  89.12%
# step : 34 / 500.0
# top-1 percentage :  70.32%
# top-5 percentage :  89.18%
# step : 35 / 500.0
# top-1 percentage :  70.26%
# top-5 percentage :  89.26%
# step : 36 / 500.0
# top-1 percentage :  69.97%
# top-5 percentage :  89.22%
# step : 37 / 500.0
# top-1 percentage :  70.05%
# top-5 percentage :  89.24%
# step : 38 / 500.0
# top-1 percentage :  70.05%
# top-5 percentage :  89.16%
# step : 39 / 500.0
# top-1 percentage :  70.03%
# top-5 percentage :  89.10%
# step : 40 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  88.83%
# step : 41 / 500.0
# top-1 percentage :  69.61%
# top-5 percentage :  88.76%
# step : 42 / 500.0
# top-1 percentage :  69.43%
# top-5 percentage :  88.69%
# step : 43 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  88.79%
# step : 44 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  88.73%
# step : 45 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  88.82%
# step : 46 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  88.80%
# step : 47 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  88.74%
# step : 48 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  88.81%
# step : 49 / 500.0
# top-1 percentage :  69.84%
# top-5 percentage :  88.96%
# step : 50 / 500.0
# top-1 percentage :  69.86%
# top-5 percentage :  88.94%
# step : 51 / 500.0
# top-1 percentage :  69.90%
# top-5 percentage :  89.00%
# step : 52 / 500.0
# top-1 percentage :  69.85%
# top-5 percentage :  88.96%
# step : 53 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  88.89%
# step : 54 / 500.0
# top-1 percentage :  69.87%
# top-5 percentage :  88.94%
# step : 55 / 500.0
# top-1 percentage :  69.89%
# top-5 percentage :  88.85%
# step : 56 / 500.0
# top-1 percentage :  69.86%
# top-5 percentage :  88.84%
# step : 57 / 500.0
# top-1 percentage :  69.79%
# top-5 percentage :  88.82%
# step : 58 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  88.74%
# step : 59 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  88.69%
# step : 60 / 500.0
# top-1 percentage :  69.53%
# top-5 percentage :  88.58%
# step : 61 / 500.0
# top-1 percentage :  69.46%
# top-5 percentage :  88.57%
# step : 62 / 500.0
# top-1 percentage :  69.39%
# top-5 percentage :  88.55%
# step : 63 / 500.0
# top-1 percentage :  69.49%
# top-5 percentage :  88.56%
# step : 64 / 500.0
# top-1 percentage :  69.58%
# top-5 percentage :  88.52%
# step : 65 / 500.0
# top-1 percentage :  69.60%
# top-5 percentage :  88.51%
# step : 66 / 500.0
# top-1 percentage :  69.56%
# top-5 percentage :  88.50%
# step : 67 / 500.0
# top-1 percentage :  69.58%
# top-5 percentage :  88.55%
# step : 68 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  88.51%
# step : 69 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  88.61%
# step : 70 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  88.67%
# step : 71 / 500.0
# top-1 percentage :  69.80%
# top-5 percentage :  88.72%
# step : 72 / 500.0
# top-1 percentage :  69.92%
# top-5 percentage :  88.75%
# step : 73 / 500.0
# top-1 percentage :  69.96%
# top-5 percentage :  88.78%
# step : 74 / 500.0
# top-1 percentage :  69.97%
# top-5 percentage :  88.77%
# step : 75 / 500.0
# top-1 percentage :  70.07%
# top-5 percentage :  88.83%
# step : 76 / 500.0
# top-1 percentage :  69.96%
# top-5 percentage :  88.83%
# step : 77 / 500.0
# top-1 percentage :  69.86%
# top-5 percentage :  88.82%
# step : 78 / 500.0
# top-1 percentage :  69.90%
# top-5 percentage :  88.79%
# step : 79 / 500.0
# top-1 percentage :  69.86%
# top-5 percentage :  88.76%
# step : 80 / 500.0
# top-1 percentage :  69.85%
# top-5 percentage :  88.84%
# step : 81 / 500.0
# top-1 percentage :  69.79%
# top-5 percentage :  88.78%
# step : 82 / 500.0
# top-1 percentage :  69.78%
# top-5 percentage :  88.78%
# step : 83 / 500.0
# top-1 percentage :  69.86%
# top-5 percentage :  88.81%
# step : 84 / 500.0
# top-1 percentage :  69.87%
# top-5 percentage :  88.82%
# step : 85 / 500.0
# top-1 percentage :  69.92%
# top-5 percentage :  88.80%
# step : 86 / 500.0
# top-1 percentage :  69.90%
# top-5 percentage :  88.77%
# step : 87 / 500.0
# top-1 percentage :  69.91%
# top-5 percentage :  88.77%
# step : 88 / 500.0
# top-1 percentage :  69.88%
# top-5 percentage :  88.76%
# step : 89 / 500.0
# top-1 percentage :  69.85%
# top-5 percentage :  88.70%
# step : 90 / 500.0
# top-1 percentage :  69.84%
# top-5 percentage :  88.68%
# step : 91 / 500.0
# top-1 percentage :  69.82%
# top-5 percentage :  88.70%
# step : 92 / 500.0
# top-1 percentage :  69.84%
# top-5 percentage :  88.68%
# step : 93 / 500.0
# top-1 percentage :  69.88%
# top-5 percentage :  88.69%
# step : 94 / 500.0
# top-1 percentage :  69.86%
# top-5 percentage :  88.70%
# step : 95 / 500.0
# top-1 percentage :  69.84%
# top-5 percentage :  88.75%
# step : 96 / 500.0
# top-1 percentage :  69.81%
# top-5 percentage :  88.74%
# step : 97 / 500.0
# top-1 percentage :  69.77%
# top-5 percentage :  88.72%
# step : 98 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  88.71%
# step : 99 / 500.0
# top-1 percentage :  69.78%
# top-5 percentage :  88.69%
# step : 100 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  88.71%
# step : 101 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  88.73%
# step : 102 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  88.73%
# step : 103 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  88.74%
# step : 104 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  88.78%
# step : 105 / 500.0
# top-1 percentage :  69.79%
# top-5 percentage :  88.77%
# step : 106 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  88.69%
# step : 107 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  88.65%
# step : 108 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  88.64%
# step : 109 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  88.62%
# step : 110 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  88.61%
# step : 111 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  88.64%
# step : 112 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  88.62%
# step : 113 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  88.62%
# step : 114 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  88.61%
# step : 115 / 500.0
# top-1 percentage :  69.55%
# top-5 percentage :  88.62%
# step : 116 / 500.0
# top-1 percentage :  69.58%
# top-5 percentage :  88.65%
# step : 117 / 500.0
# top-1 percentage :  69.54%
# top-5 percentage :  88.66%
# step : 118 / 500.0
# top-1 percentage :  69.53%
# top-5 percentage :  88.62%
# step : 119 / 500.0
# top-1 percentage :  69.50%
# top-5 percentage :  88.60%
# step : 120 / 500.0
# top-1 percentage :  69.53%
# top-5 percentage :  88.59%
# step : 121 / 500.0
# top-1 percentage :  69.55%
# top-5 percentage :  88.60%
# step : 122 / 500.0
# top-1 percentage :  69.58%
# top-5 percentage :  88.60%
# step : 123 / 500.0
# top-1 percentage :  69.56%
# top-5 percentage :  88.59%
# step : 124 / 500.0
# top-1 percentage :  69.54%
# top-5 percentage :  88.56%
# step : 125 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  88.58%
# step : 126 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  88.60%
# step : 127 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  88.56%
# step : 128 / 500.0
# top-1 percentage :  69.56%
# top-5 percentage :  88.53%
# step : 129 / 500.0
# top-1 percentage :  69.57%
# top-5 percentage :  88.57%
# step : 130 / 500.0
# top-1 percentage :  69.59%
# top-5 percentage :  88.57%
# step : 131 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  88.62%
# step : 132 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  88.60%
# step : 133 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  88.64%
# step : 134 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  88.69%
# step : 135 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  88.72%
# step : 136 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  88.68%
# step : 137 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  88.64%
# step : 138 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  88.64%
# step : 139 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  88.66%
# step : 140 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  88.67%
# step : 141 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  88.69%
# step : 142 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  88.68%
# step : 143 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  88.71%
# step : 144 / 500.0
# top-1 percentage :  69.77%
# top-5 percentage :  88.74%
# step : 145 / 500.0
# top-1 percentage :  69.78%
# top-5 percentage :  88.73%
# step : 146 / 500.0
# top-1 percentage :  69.78%
# top-5 percentage :  88.76%
# step : 147 / 500.0
# top-1 percentage :  69.78%
# top-5 percentage :  88.71%
# step : 148 / 500.0
# top-1 percentage :  69.78%
# top-5 percentage :  88.70%
# step : 149 / 500.0
# top-1 percentage :  69.82%
# top-5 percentage :  88.73%
# step : 150 / 500.0
# top-1 percentage :  69.83%
# top-5 percentage :  88.75%
# step : 151 / 500.0
# top-1 percentage :  69.79%
# top-5 percentage :  88.73%
# step : 152 / 500.0
# top-1 percentage :  69.82%
# top-5 percentage :  88.73%
# step : 153 / 500.0
# top-1 percentage :  69.82%
# top-5 percentage :  88.73%
# step : 154 / 500.0
# top-1 percentage :  69.79%
# top-5 percentage :  88.75%
# step : 155 / 500.0
# top-1 percentage :  69.81%
# top-5 percentage :  88.76%
# step : 156 / 500.0
# top-1 percentage :  69.81%
# top-5 percentage :  88.78%
# step : 157 / 500.0
# top-1 percentage :  69.84%
# top-5 percentage :  88.80%
# step : 158 / 500.0
# top-1 percentage :  69.85%
# top-5 percentage :  88.80%
# step : 159 / 500.0
# top-1 percentage :  69.82%
# top-5 percentage :  88.82%
# step : 160 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  88.79%
# step : 161 / 500.0
# top-1 percentage :  69.78%
# top-5 percentage :  88.83%
# step : 162 / 500.0
# top-1 percentage :  69.80%
# top-5 percentage :  88.83%
# step : 163 / 500.0
# top-1 percentage :  69.79%
# top-5 percentage :  88.83%
# step : 164 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  88.83%
# step : 165 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  88.82%
# step : 166 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  88.84%
# step : 167 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  88.83%
# step : 168 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  88.85%
# step : 169 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  88.83%
# step : 170 / 500.0
# top-1 percentage :  69.58%
# top-5 percentage :  88.83%
# step : 171 / 500.0
# top-1 percentage :  69.59%
# top-5 percentage :  88.83%
# step : 172 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  88.86%
# step : 173 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  88.86%
# step : 174 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  88.87%
# step : 175 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  88.86%
# step : 176 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  88.86%
# step : 177 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  88.88%
# step : 178 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  88.84%
# step : 179 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  88.84%
# step : 180 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  88.84%
# step : 181 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  88.86%
# step : 182 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  88.84%
# step : 183 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  88.85%
# step : 184 / 500.0
# top-1 percentage :  69.61%
# top-5 percentage :  88.84%
# step : 185 / 500.0
# top-1 percentage :  69.61%
# top-5 percentage :  88.85%
# step : 186 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  88.88%
# step : 187 / 500.0
# top-1 percentage :  69.56%
# top-5 percentage :  88.86%
# step : 188 / 500.0
# top-1 percentage :  69.55%
# top-5 percentage :  88.85%
# step : 189 / 500.0
# top-1 percentage :  69.58%
# top-5 percentage :  88.87%
# step : 190 / 500.0
# top-1 percentage :  69.59%
# top-5 percentage :  88.88%
# step : 191 / 500.0
# top-1 percentage :  69.60%
# top-5 percentage :  88.89%
# step : 192 / 500.0
# top-1 percentage :  69.59%
# top-5 percentage :  88.89%
# step : 193 / 500.0
# top-1 percentage :  69.61%
# top-5 percentage :  88.88%
# step : 194 / 500.0
# top-1 percentage :  69.61%
# top-5 percentage :  88.90%
# step : 195 / 500.0
# top-1 percentage :  69.60%
# top-5 percentage :  88.90%
# step : 196 / 500.0
# top-1 percentage :  69.57%
# top-5 percentage :  88.89%
# step : 197 / 500.0
# top-1 percentage :  69.60%
# top-5 percentage :  88.90%
# step : 198 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  88.92%
# step : 199 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  88.91%
# step : 200 / 500.0
# top-1 percentage :  69.57%
# top-5 percentage :  88.92%
# step : 201 / 500.0
# top-1 percentage :  69.56%
# top-5 percentage :  88.94%
# step : 202 / 500.0
# top-1 percentage :  69.56%
# top-5 percentage :  88.92%
# step : 203 / 500.0
# top-1 percentage :  69.58%
# top-5 percentage :  88.93%
# step : 204 / 500.0
# top-1 percentage :  69.59%
# top-5 percentage :  88.95%
# step : 205 / 500.0
# top-1 percentage :  69.59%
# top-5 percentage :  88.96%
# step : 206 / 500.0
# top-1 percentage :  69.63%
# top-5 percentage :  88.95%
# step : 207 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  88.95%
# step : 208 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  88.94%
# step : 209 / 500.0
# top-1 percentage :  69.60%
# top-5 percentage :  88.93%
# step : 210 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  88.94%
# step : 211 / 500.0
# top-1 percentage :  69.60%
# top-5 percentage :  88.95%
# step : 212 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  88.97%
# step : 213 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  88.98%
# step : 214 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  88.95%
# step : 215 / 500.0
# top-1 percentage :  69.60%
# top-5 percentage :  88.94%
# step : 216 / 500.0
# top-1 percentage :  69.63%
# top-5 percentage :  88.94%
# step : 217 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  88.94%
# step : 218 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  88.95%
# step : 219 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  88.95%
# step : 220 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  88.96%
# step : 221 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  88.97%
# step : 222 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  88.97%
# step : 223 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  88.98%
# step : 224 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  88.98%
# step : 225 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  88.98%
# step : 226 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  88.99%
# step : 227 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  89.00%
# step : 228 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  89.00%
# step : 229 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  88.97%
# step : 230 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  88.97%
# step : 231 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  88.98%
# step : 232 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  88.97%
# step : 233 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  88.99%
# step : 234 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  89.00%
# step : 235 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.00%
# step : 236 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.01%
# step : 237 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.01%
# step : 238 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  88.99%
# step : 239 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  89.00%
# step : 240 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  89.02%
# step : 241 / 500.0
# top-1 percentage :  69.63%
# top-5 percentage :  89.01%
# step : 242 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  89.03%
# step : 243 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  89.03%
# step : 244 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  89.02%
# step : 245 / 500.0
# top-1 percentage :  69.63%
# top-5 percentage :  89.02%
# step : 246 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  89.03%
# step : 247 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  89.03%
# step : 248 / 500.0
# top-1 percentage :  69.60%
# top-5 percentage :  89.03%
# step : 249 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  89.04%
# step : 250 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  89.03%
# step : 251 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  89.05%
# step : 252 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  89.06%
# step : 253 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  89.08%
# step : 254 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.09%
# step : 255 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.10%
# step : 256 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.09%
# step : 257 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.08%
# step : 258 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  89.10%
# step : 259 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  89.10%
# step : 260 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  89.09%
# step : 261 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.07%
# step : 262 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.10%
# step : 263 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.10%
# step : 264 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.10%
# step : 265 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.11%
# step : 266 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.08%
# step : 267 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.09%
# step : 268 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.09%
# step : 269 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.09%
# step : 270 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.11%
# step : 271 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  89.11%
# step : 272 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.11%
# step : 273 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.12%
# step : 274 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.13%
# step : 275 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.13%
# step : 276 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.13%
# step : 277 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.14%
# step : 278 / 500.0
# top-1 percentage :  69.77%
# top-5 percentage :  89.15%
# step : 279 / 500.0
# top-1 percentage :  69.77%
# top-5 percentage :  89.14%
# step : 280 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.16%
# step : 281 / 500.0
# top-1 percentage :  69.80%
# top-5 percentage :  89.14%
# step : 282 / 500.0
# top-1 percentage :  69.83%
# top-5 percentage :  89.15%
# step : 283 / 500.0
# top-1 percentage :  69.84%
# top-5 percentage :  89.16%
# step : 284 / 500.0
# top-1 percentage :  69.85%
# top-5 percentage :  89.17%
# step : 285 / 500.0
# top-1 percentage :  69.83%
# top-5 percentage :  89.16%
# step : 286 / 500.0
# top-1 percentage :  69.82%
# top-5 percentage :  89.17%
# step : 287 / 500.0
# top-1 percentage :  69.83%
# top-5 percentage :  89.19%
# step : 288 / 500.0
# top-1 percentage :  69.82%
# top-5 percentage :  89.20%
# step : 289 / 500.0
# top-1 percentage :  69.81%
# top-5 percentage :  89.21%
# step : 290 / 500.0
# top-1 percentage :  69.78%
# top-5 percentage :  89.21%
# step : 291 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.20%
# step : 292 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.17%
# step : 293 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.16%
# step : 294 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.16%
# step : 295 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.17%
# step : 296 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.19%
# step : 297 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.18%
# step : 298 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.18%
# step : 299 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.18%
# step : 300 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.17%
# step : 301 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.17%
# step : 302 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.17%
# step : 303 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.16%
# step : 304 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.15%
# step : 305 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.14%
# step : 306 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.12%
# step : 307 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.11%
# step : 308 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.12%
# step : 309 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.12%
# step : 310 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.13%
# step : 311 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  89.14%
# step : 312 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.15%
# step : 313 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.15%
# step : 314 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.15%
# step : 315 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.16%
# step : 316 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.16%
# step : 317 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.15%
# step : 318 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.14%
# step : 319 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.14%
# step : 320 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.15%
# step : 321 / 500.0
# top-1 percentage :  69.77%
# top-5 percentage :  89.16%
# step : 322 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.16%
# step : 323 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.16%
# step : 324 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.18%
# step : 325 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.18%
# step : 326 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.17%
# step : 327 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.17%
# step : 328 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.15%
# step : 329 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.14%
# step : 330 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.14%
# step : 331 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.14%
# step : 332 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  89.13%
# step : 333 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  89.15%
# step : 334 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  89.15%
# step : 335 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  89.15%
# step : 336 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.16%
# step : 337 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.16%
# step : 338 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.17%
# step : 339 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.16%
# step : 340 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.16%
# step : 341 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.16%
# step : 342 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.15%
# step : 343 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.15%
# step : 344 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.14%
# step : 345 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  89.13%
# step : 346 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  89.13%
# step : 347 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.12%
# step : 348 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.12%
# step : 349 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.12%
# step : 350 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.13%
# step : 351 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.13%
# step : 352 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.14%
# step : 353 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.14%
# step : 354 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.15%
# step : 355 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  89.16%
# step : 356 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.15%
# step : 357 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.15%
# step : 358 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.16%
# step : 359 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.16%
# step : 360 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.15%
# step : 361 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  89.16%
# step : 362 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  89.15%
# step : 363 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.15%
# step : 364 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  89.14%
# step : 365 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.15%
# step : 366 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  89.14%
# step : 367 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  89.13%
# step : 368 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.12%
# step : 369 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  89.12%
# step : 370 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  89.12%
# step : 371 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.12%
# step : 372 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  89.12%
# step : 373 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.12%
# step : 374 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  89.11%
# step : 375 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  89.10%
# step : 376 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  89.11%
# step : 377 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  89.11%
# step : 378 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  89.11%
# step : 379 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  89.10%
# step : 380 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  89.07%
# step : 381 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  89.08%
# step : 382 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  89.08%
# step : 383 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  89.07%
# step : 384 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  89.07%
# step : 385 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  89.06%
# step : 386 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  89.06%
# step : 387 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  89.06%
# step : 388 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  89.06%
# step : 389 / 500.0
# top-1 percentage :  69.63%
# top-5 percentage :  89.04%
# step : 390 / 500.0
# top-1 percentage :  69.63%
# top-5 percentage :  89.05%
# step : 391 / 500.0
# top-1 percentage :  69.63%
# top-5 percentage :  89.05%
# step : 392 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  89.06%
# step : 393 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  89.05%
# step : 394 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  89.05%
# step : 395 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  89.06%
# step : 396 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  89.06%
# step : 397 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  89.05%
# step : 398 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  89.04%
# step : 399 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  89.04%
# step : 400 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  89.04%
# step : 401 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  89.05%
# step : 402 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  89.07%
# step : 403 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  89.07%
# step : 404 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.07%
# step : 405 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.07%
# step : 406 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.07%
# step : 407 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.08%
# step : 408 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  89.07%
# step : 409 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  89.07%
# step : 410 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  89.05%
# step : 411 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  89.04%
# step : 412 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  89.03%
# step : 413 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  89.04%
# step : 414 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  89.04%
# step : 415 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  89.04%
# step : 416 / 500.0
# top-1 percentage :  69.63%
# top-5 percentage :  89.04%
# step : 417 / 500.0
# top-1 percentage :  69.63%
# top-5 percentage :  89.04%
# step : 418 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  89.04%
# step : 419 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  89.03%
# step : 420 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  89.03%
# step : 421 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  89.03%
# step : 422 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  89.03%
# step : 423 / 500.0
# top-1 percentage :  69.60%
# top-5 percentage :  89.01%
# step : 424 / 500.0
# top-1 percentage :  69.59%
# top-5 percentage :  89.00%
# step : 425 / 500.0
# top-1 percentage :  69.59%
# top-5 percentage :  89.01%
# step : 426 / 500.0
# top-1 percentage :  69.58%
# top-5 percentage :  89.01%
# step : 427 / 500.0
# top-1 percentage :  69.58%
# top-5 percentage :  89.01%
# step : 428 / 500.0
# top-1 percentage :  69.58%
# top-5 percentage :  89.00%
# step : 429 / 500.0
# top-1 percentage :  69.59%
# top-5 percentage :  89.01%
# step : 430 / 500.0
# top-1 percentage :  69.60%
# top-5 percentage :  89.02%
# step : 431 / 500.0
# top-1 percentage :  69.60%
# top-5 percentage :  89.01%
# step : 432 / 500.0
# top-1 percentage :  69.61%
# top-5 percentage :  89.02%
# step : 433 / 500.0
# top-1 percentage :  69.61%
# top-5 percentage :  89.02%
# step : 434 / 500.0
# top-1 percentage :  69.61%
# top-5 percentage :  89.02%
# step : 435 / 500.0
# top-1 percentage :  69.60%
# top-5 percentage :  89.01%
# step : 436 / 500.0
# top-1 percentage :  69.62%
# top-5 percentage :  89.02%
# step : 437 / 500.0
# top-1 percentage :  69.61%
# top-5 percentage :  89.01%
# step : 438 / 500.0
# top-1 percentage :  69.60%
# top-5 percentage :  89.00%
# step : 439 / 500.0
# top-1 percentage :  69.61%
# top-5 percentage :  89.00%
# step : 440 / 500.0
# top-1 percentage :  69.61%
# top-5 percentage :  89.00%
# step : 441 / 500.0
# top-1 percentage :  69.61%
# top-5 percentage :  89.01%
# step : 442 / 500.0
# top-1 percentage :  69.63%
# top-5 percentage :  89.02%
# step : 443 / 500.0
# top-1 percentage :  69.63%
# top-5 percentage :  89.02%
# step : 444 / 500.0
# top-1 percentage :  69.63%
# top-5 percentage :  89.02%
# step : 445 / 500.0
# top-1 percentage :  69.64%
# top-5 percentage :  89.03%
# step : 446 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  89.02%
# step : 447 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  89.02%
# step : 448 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  89.01%
# step : 449 / 500.0
# top-1 percentage :  69.65%
# top-5 percentage :  89.02%
# step : 450 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  89.03%
# step : 451 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  89.03%
# step : 452 / 500.0
# top-1 percentage :  69.66%
# top-5 percentage :  89.03%
# step : 453 / 500.0
# top-1 percentage :  69.67%
# top-5 percentage :  89.04%
# step : 454 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.04%
# step : 455 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.04%
# step : 456 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.03%
# step : 457 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  89.03%
# step : 458 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.04%
# step : 459 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  89.05%
# step : 460 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  89.04%
# step : 461 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  89.05%
# step : 462 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.04%
# step : 463 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.05%
# step : 464 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.05%
# step : 465 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.04%
# step : 466 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.05%
# step : 467 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  89.05%
# step : 468 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.03%
# step : 469 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.03%
# step : 470 / 500.0
# top-1 percentage :  69.68%
# top-5 percentage :  89.02%
# step : 471 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.03%
# step : 472 / 500.0
# top-1 percentage :  69.69%
# top-5 percentage :  89.02%
# step : 473 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  89.02%
# step : 474 / 500.0
# top-1 percentage :  69.70%
# top-5 percentage :  89.01%
# step : 475 / 500.0
# top-1 percentage :  69.71%
# top-5 percentage :  89.03%
# step : 476 / 500.0
# top-1 percentage :  69.72%
# top-5 percentage :  89.05%
# step : 477 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.05%
# step : 478 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.05%
# step : 479 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.05%
# step : 480 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.05%
# step : 481 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.06%
# step : 482 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.06%
# step : 483 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.07%
# step : 484 / 500.0
# top-1 percentage :  69.77%
# top-5 percentage :  89.08%
# step : 485 / 500.0
# top-1 percentage :  69.77%
# top-5 percentage :  89.08%
# step : 486 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.08%
# step : 487 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.08%
# step : 488 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.08%
# step : 489 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.08%
# step : 490 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.08%
# step : 491 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.08%
# step : 492 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.08%
# step : 493 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.07%
# step : 494 / 500.0
# top-1 percentage :  69.73%
# top-5 percentage :  89.07%
# step : 495 / 500.0
# top-1 percentage :  69.74%
# top-5 percentage :  89.08%
# step : 496 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.08%
# step : 497 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.08%
# step : 498 / 500.0
# top-1 percentage :  69.75%
# top-5 percentage :  89.08%
# step : 499 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.08%
# step : 500 / 500.0
# top-1 percentage :  69.76%
# top-5 percentage :  89.07%
# top-1 percentage :  69.76%
# top-5 percentage :  89.07%
